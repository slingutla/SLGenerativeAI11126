# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

load_dotenv(override=True, dotenv_path="../.env.local")
my_api_key = os.getenv("OPENAI_API_KEY")

print(f"my api key is:[{my_api_key[:4]}...{my_api_key[-4:]}]")
# Out:
# my api key is:[sk-p...9KYA]

# %%
my_client = OpenAI(api_key=my_api_key)
# my_client

def ask_question_open_ai(prompt):

    # print(f"User asked: {prompt}")
    # my_client.chat.completions.create

    llm_response = my_client.chat.completions.create(
        model="gpt-5-nano",
        messages=[
            {"role": "system", "content": "You are a helpful assistant. Answer as concisely as possible."},
            {"role": "user", "content": prompt}
        ]
    )
    return llm_response.choices[0].message.content

# %%
import ollama

def ask_question_local_llm(prompt):
    # print(f"User asked: {prompt}")
    # my_client.chat.completions.create

    # Run a prompt against a local model (e.g., llama2)
    response = ollama.chat(
        model='llama3',
        messages=[
            {"role": "system", "content": "You are a helpful AI assitant - Respond in one line"},
            {"role": "user", "content": prompt}
        ]
    )
    return response['message']['content']

# %%
prompt = "What is the capital of France?"

response_local_llm = ask_question_local_llm(prompt)
response_open_ai = ask_question_open_ai(prompt)

print(f"Response from local LLM: {response_local_llm}")
print(f"Response from OpenAI: {response_open_ai}")
# Out:
# Response from local LLM: The capital of France is Paris.
# Response from OpenAI: Paris.

# %%
import time
while True:
    # Ask user for a question
    user_prompt = input("Ask something: ")

    if (user_prompt.lower() != 'quit'):
        # Get and print the response
        print ("-------------------OPEN AI RESPONSE-------------------")
        start = time.time()
        response_openai = ask_question_open_ai(user_prompt)
        end = time.time()   
        print(f"Time taken by OpenAI: {end - start} seconds")
        print("\nOpenAI says:", response_openai)

        print ("\n\n-------------------LOCAL LLM RESPONSE-------------------")
        start = time.time()
        response_local = ask_question_local_llm(user_prompt)
        end = time.time()   
        print(f"Time taken by Local LLM: {end - start} seconds")
        print("\nLocal LLM says:", response_local)        

        # add delay of 3 seconds
        time.sleep(3)
    else:
        print("Exiting...")
        break
# Out:
# -------------------OPEN AI RESPONSE-------------------
# Time taken by OpenAI: 21.830764532089233 seconds
#
# OpenAI says: Here’s a quick overview of Venezuela:
#
# - Where and people: Northern South America, bordered by Colombia, Brazil, Guyana, and the Caribbean. Capital and largest city: Caracas. Official language: Spanish. Population roughly in the tens of millions; significant diaspora abroad.
#
# - Geography and nature: Very diverse scenery—Andes in the west, vast Llanos plains, the Amazon rainforest’s edge in the south, and a long Caribbean coast. Notable sights include Angel Falls and Canaima National Park; rich biodiversity and many national parks.
#
# - Economy: Historically oil-rich; crude oil has been the backbone of the economy. In recent years the country faced a severe economic crisis, with hyperinflation, currency volatility, shortages of goods, and a large emigration. Sanctions and governance tensions have also shaped the economy and daily life.
#
# - Politics and society: Long-running political tensions between the government and opposition. Since the 2010s, leadership and legitimacy have been contested by many domestic and international actors. The situation remains dynamic, affecting public services, security, and everyday life.
#
# - Culture and daily life: Rich cultural traditions, including music (joropo, salsa), dance, and a cuisine featuring arepas, pabellón criollo, and hallacas. Baseball is popular; Venezuelan literature and art have notable figures as well.
#
# - Travel and safety notes: Safety can vary by region; demonstrations and civil unrest can occur. If you’re planning a visit, check current travel advisories, have flexible plans, and be mindful of cash and payment options in markets and smaller towns.
#
# If you tell me what you’re most curious about (history, current events, travel tips, culture, or economy), I can go deeper.
#
#
# -------------------LOCAL LLM RESPONSE-------------------
# Time taken by Local LLM: 1.254849910736084 seconds
#
# Local LLM says: Venezuela is a country located on the northern coast of South America, bordering Colombia and Guyana, with a rich cultural heritage, diverse wildlife, and complex political situation marked by economic crisis and political instability.
# Exiting...
