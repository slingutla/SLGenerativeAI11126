# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

load_dotenv(override=True, dotenv_path="../.env")
my_api_key = os.getenv("OPENAI_API_KEY")

print(f"my api key is{my_api_key}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 8
#       5 load_dotenv(override=True, dotenv_path="../.env")
#       6 my_api_key = os.getenv("OPENAI_API_KEY")
# ----> 8 print("Using API Key:", my_api_key[:5] + "..." + my_api_key[-5:])
#
# TypeError: 'NoneType' object is not subscriptable

# %%
import ollama

def ask_question_local_llm(prompt):
    # print(f"User asked: {prompt}")
    # my_client.chat.completions.create

    # Run a prompt against a local model (e.g., llama2)
    response = ollama.chat(
        model='llama3',
        messages=[
            {"role": "system", "content": "You are a helpful AI assitant - Respond in one line"},
            {"role": "user", "content": prompt}
        ]
    )
    return response['message']['content']
