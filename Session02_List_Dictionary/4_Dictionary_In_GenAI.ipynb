# %%
# Key Value Pair
messages_history = {"user_prompt": "When does it rain in California?",
            "system_response": "It rains in Fall"}


print (messages_history["system_response"])  # It rains in Fall


messages_history.get("system_response")  # It rains in Fall
# Out:
# It rains in Fall
# 'It rains in Fall'

# %%
message_user = {"role": "user", "content": "When does it rain in California?"}
message_system = {"role": "system", "content": "It rains in Fall"}  

messages = [message_user, message_system] # List of Dictionary

i=0
for message in messages:
    print(f" {i+1}: {message['role']} says {message['content']}")
    i+=1
# Out:
#  1: user says When does it rain in California?
#  2: system says It rains in Fall
