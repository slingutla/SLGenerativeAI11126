# %%
person = {
	"name": "Alice",
	"age": 30,
	"is_student": False,
	"address": "123 Main St"
}

for key in person:
	print(key, ":", person[key])

# %%
print(person["name"])
print(person.get("name", "Unknown"))
print(person["age"])
print(person.get("is_student", "Not Available"))
  # This will raise a KeyError

# %%
print(person.get("address", "Not Available"))

# %%
del person["is_student"]

# %%
person_1 = {
	"name": "Alice",
	"age": 30,
	"is_student": False
}

person_2 = {
	"name": "Jim",
	"age": 20,
	"is_student": True
}

classroom = [person_1, person_2]

# Give me ages for all persons in the classroom
ages =[person["age"] for person in classroom]
print(ages)

#for person in classroom:
 #   print(person["age"])

for person in classroom:
    print(person["age"])

# %%
#Exception handling while accessing a non-existing key
try:
    del person["is_student"]
except KeyError as e:
    print(f"KeyError encountered: {e}")
# Out:
# KeyError encountered: 'is_student'

# %%
try:
    a =10
    b=0
    result = a / b
except Exception as e:
    print(f"Error in division: {e}")
# Out:
# Error in division: division by zero

# %%
print(person)
print(person.pop("age"))
print(person)
# Out:
# {'name': 'Jim', 'age': 20}
# 20
# {'name': 'Jim'}

# %%
person1 = {
	"name": "Alice",
	"age": 30,
	"is_student": False
}
person2 = {
	"name": "Mark",
	"age": 34,
	"is_student": False
}
persons = [person1, person2] #List of dictionaries

for person in persons:
    for key in person:
	    print(key, ":", person[key])
# Out:
# name : Alice
# age : 30
# is_student : False
# name : Mark
# age : 34
# is_student : False
