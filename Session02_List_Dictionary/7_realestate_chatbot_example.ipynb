# %%
#%pip install openai python-dotenv

# %%
import os
from dotenv import load_dotenv

# %%
load_dotenv(override=True, dotenv_path="../.env.local")
my_api_key = os.getenv("OPENAI_API_KEY")

print (my_api_key[:5] + "..." + my_api_key[-5:])
# Out:
# sk-pr...u9KYA

# %%
from openai import OpenAI
from langsmith import traceable
client = OpenAI(api_key=my_api_key)
@traceable
def ask_question(prompt):
    print(f"User asked: {prompt}")
    response = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "You are a creative property listing assistant that generates a very cool property description based on the user input. Be creative!"},
            {"role": "user", "content": prompt}
        ]
    )
    print (response)
    return response.choices[0].message.content  
    # response.choices[0].message.content

# %%
user_prompt = input("Ask something: ")

response = ask_question(user_prompt)
print("\nOpenAI says:", response)
# Out:
# User asked: Home prices trends around Santa Monica
# ChatCompletion(id='chatcmpl-DA75N48U5Mt7IbRHQLmluWaXatZYz', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="🌟 Welcome to the trendiest neighborhood of Santa Monica! 🌟 \n\nAre you ready to immerse yourself in the vibrant lifestyle of this seaside gem? Santa Monica is not just a place to live, it's a way of life! From trendy boutiques to world-class dining, this neighborhood has it all.\n\nHome prices here are as hot as the California sun, but don't let that deter you! Investing in a property in Santa Monica means investing in a lifestyle of luxury and leisure. Imagine waking up to the sound of ocean waves and ending your day with a breathtaking sunset over the Pacific Ocean. \n\nWhether you're looking for a cozy beach bungalow or a modern upscale condo, Santa Monica offers a diverse range of real estate options to cater to every taste. So why wait? Start your journey to coastal living today and make Santa Monica your home sweet home! 🌴🏠✨", refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1771302889, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=184, prompt_tokens=40, total_tokens=224, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
#
# OpenAI says: 🌟 Welcome to the trendiest neighborhood of Santa Monica! 🌟
#
# Are you ready to immerse yourself in the vibrant lifestyle of this seaside gem? Santa Monica is not just a place to live, it's a way of life! From trendy boutiques to world-class dining, this neighborhood has it all.
#
# Home prices here are as hot as the California sun, but don't let that deter you! Investing in a property in Santa Monica means investing in a lifestyle of luxury and leisure. Imagine waking up to the sound of ocean waves and ending your day with a breathtaking sunset over the Pacific Ocean.
#
# Whether you're looking for a cozy beach bungalow or a modern upscale condo, Santa Monica offers a diverse range of real estate options to cater to every taste. So why wait? Start your journey to coastal living today and make Santa Monica your home sweet home! 🌴🏠✨

# %%
import time
while True:
    # Ask user for a question
    user_prompt = input("Ask something: ")

    if (user_prompt.lower() != 'quit'):
        # Get and print the response
        response = ask_question(user_prompt)
        print("\nOpenAI says:", response)
        
        # add delay of 3 seconds
        time.sleep(3)
    else:
        print("Exiting the loop. Goodbye!")
        break
