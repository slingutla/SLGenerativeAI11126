# %%
# %pip install fastmcp duckduckgo-search

# %%
# %pip install ddgs

# %%
# %pip install googlesearch-python

# %%
# API for fastmcp 2.12.5
import asyncio
from fastmcp import Client
transport = "http://127.0.0.1:8765/mcp"

async with Client(transport) as client:
    query = "movies"
    result = await client.call_tool("search_web", {"query": query, "max_results": 5})
    
    
    data = result.structured_content or result.data
    print("\nSearch Results:\n", data)
# Out:
# Search Results:
#  {'status': 'success', 'query': 'movies', 'count': 5, 'results': [{'title': 'Regal Coldwater Crossing Movie Tickets and Showtimes | Regal', 'href': 'https://www.regmovies.com/theatres/regal-coldwater-crossing-0169', 'body': 'Get showtimes, buy movie tickets and more at Regal Coldwater Crossing movie theatre in Fort Wayne, IN. Discover it all at a Regal movie …'}, {'title': 'Regal Louisiana Boardwalk Movie Tickets and Showtimes | Regal', 'href': 'https://www.regmovies.com/theatres/regal-louisiana-boardwalk-0664', 'body': 'Get showtimes, buy movie tickets and more at Regal Louisiana Boardwalk movie theatre in Bossier City, LA. Discover it all at a Regal …'}, {'title': 'Regal Stonestown Galleria Movie Tickets and Showtimes | Regal', 'href': 'https://www.regmovies.com/theatres/regal-stonestown-galleria-1464', 'body': 'Get showtimes, buy movie tickets and more at Regal Stonestown Galleria movie theatre in San Francisco, CA. Discover it all at a Regal movie …'}, {'title': 'Regal UA Sheepshead Bay Movie Tickets and Showtimes | Regal', 'href': 'https://www.regmovies.com/theatres/regal-ua-sheepshead-bay-1159', 'body': 'Get showtimes, buy movie tickets and more at Regal UA Sheepshead Bay movie theatre in Brooklyn, NY. Discover it all at a Regal movie …'}, {'title': 'Regal Edwards Aliso Viejo Movie Tickets and Showtimes | Regal', 'href': 'https://www.regmovies.com/theatres/regal-edwards-aliso-viejo-1032', 'body': 'Get showtimes, buy movie tickets and more at Regal Edwards Aliso Viejo movie theatre in Aliso Viejo, CA. Discover it all at a Regal movie …'}]}

# %%
# API for fastmcp 2.12.5
import asyncio
from fastmcp import Client
transport = "http://127.0.0.1:8765/mcp"

async with Client(transport) as client:
    query = "super bowl latest updates"
    result = await client.call_tool("search_web", {"query": query, "max_results": 5})

    data = result.structured_content or result.data
    print("\nSearch Results:\n", data)
