# %%
print ("Hello AI World!")

# %%
name = "Alice"
score = 95
print(f"{name} scored {score} in the test.")
# Out:
# Alice scored 95 in the test.

# %%
age_str = input("Enter your age: ")
age = int(age_str)
print("Hello", age)
print(f"Hello, {age}")
# Out:
# Hello 43
# Hello, 43

# %%
from random import random

x = random() * 10
print(f"Generated number: {x}")

if x > 5:
	print("x is greater than 5")
else:
	print("x is 5 or less")
# Out:
# Generated number: 4.115185252977488
# x is 5 or less

# %%
i = 1
while i <= 5:
	print(i)
	i += 1
# Out:
# 1
# 2
# 3
# 4
# 5
