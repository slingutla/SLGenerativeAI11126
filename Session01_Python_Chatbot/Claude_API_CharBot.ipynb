# %%
import os
from dotenv import load_dotenv

from anthropic import Anthropic


load_dotenv(override=True, dotenv_path="../.env.local")
my_api_key = os.getenv("ANTHROPIC_API_KEY")
my_api_key[:5], my_api_key[-10:]
client = Anthropic(api_key=my_api_key)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 4
#       1 import os
#       2 from dotenv import load_dotenv
# ----> 4 from anthropic import Anthropic, ClaudeAI
#       7 load_dotenv(override=True, dotenv_path="../.env.local")
#       8 my_api_key = os.getenv("ANTHROPIC_API_KEY")
#
# ImportError: cannot import name 'ClaudeAI' from 'anthropic' (c:\Users\sarat\Downloads\GENAI\Training\SLGenerativeAI11126\.venv\Lib\site-packages\anthropic\__init__.py)

# %%
def get_response_from_model(prompt):
    response = client.chat.completions.create(
    model="gpt-5-nano",
    messages=[
        {"role": "system", "content": "You are a helpful assistant. Answer as a csv fields title, description, time_data_extracted"},
        {"role": "user", "content": prompt}
        # {"role": "user", "content": f"Here is the context: \n\ {context} \n\. \n\n Now, answer the question: {prompt}")
    ]
)
    # print (response)
    # print (response.choices[0].message.content)
    return response.choices[0].message.content

# %%
import time
while True:
    # Ask user for a question
    user_prompt = input("Ask something: ")

    if (user_prompt.lower() != 'quit'):
        # Get and print the response
        response = get_response_from_model(user_prompt)
        print("\nOpenAI says:", response)
        
        # add delay of 3 seconds
        time.sleep(3)
    else:
        print("Exiting the loop. Goodbye!")
        break
# Out:
# OpenAI says: title,description,time_data_extracted
# "Yamaha Tenere 700 – Core specs (base model)","Model: Tenere 700 (base); Engine: 689cc liquid-cooled parallel-twin with 270° crank; 8 valves; DOHC; Transmission: 6-speed; Clutch: wet; Power: ~72 hp @ ~9,000 rpm; Torque: ~68 Nm @ ~6,500 rpm; Frame: steel tubular; Front suspension: 43mm inverted fork (~210 mm travel); Rear suspension: mono‑shock with linkage (~200 mm travel); Wheelbase: ~1,470 mm; Ground clearance: ~240 mm; Seat height: ~875 mm; Brakes: dual front discs and single rear disc with ABS; Wheels: 21\" front / 18\" rear (spoked); Fuel capacity: ~16 L; Curb weight: ~205 kg; Riding aids: 2-mode power map, traction control, 2-channel ABS; Instrumentation: digital display (color TFT on newer models) and gear indicator.","2026-05-17"
# "Yamaha Tenere 700 World Raid – key differences","Variant focusing on long-range touring; Fuel tank: ~23 L; Windscreen: taller; Skid plate and bash protections; Taller seat in some trims; Weight: typically higher than base (~210–215 kg curb); Brakes and suspension same basic spec but tuned for endurance; Electronics similar with riding modes, cornering ABS; Official specs vary by year; range improved due to tank; check model year for exact numbers.","2026-05-17"
# "Engine and performance overview","Displacement: 689cc; Configuration: parallel-twin, 270° crank; Cooling: liquid; Valves: 8; Power: ~72 hp; Torque: ~68 Nm; Redline around 9,000 rpm; Emissions: Euro 5 (some years).","2026-05-17"
# "Chassis, suspension and dimensions","Chassis: steel tubular frame; Front suspension: 43mm USD forks; Rear: mono-shock with linkage; Travel: ~210 mm (front), ~200 mm (rear); Ground clearance: ~240 mm; Seat height: ~875 mm; Wheel sizes: 21\" front, 18\" rear; Brakes: front dual discs; rear single disc; ABS.","2026-05-17"
# "Fuel, weights, and tires","Fuel capacity: 16 L base; 23 L World Raid; Curb weight: ~205 kg base; Tires: 90/90-21 front and 150/70-18 rear on spoked rims; Tires may vary by trim.","2026-05-17"
# Exiting the loop. Goodbye!
